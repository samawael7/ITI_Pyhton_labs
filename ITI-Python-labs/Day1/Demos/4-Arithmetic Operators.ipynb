# %% [markdown]
# ### Arithmetic operators

# %% [markdown]
# ### **(+)Addition**

# %%
20 + 10.2 # Expressions
# Out:
# 30.2

# %% [markdown]
# ### **(-) Subtraction**

# %%
20 - 10
# Out:
# 10

# %% [markdown]
# ### **(*)Multiplication**

# %%
10 * 10
# Out:
# 100

# %% [markdown]
# ### **(/) Division**

# %%
print(20 / 10)
print(type(20 / 10))
# Out:
# 2.0
# <class 'float'>

# %% [markdown]
# ### **(%) Modulus**

# %%
10 % 2
# Out:
# 0

# %%
11 % 2
# Out:
# 1

# %% [markdown]
# ### **(//) Division without Fractions**

# %%
20//10

10//3
# Out:
# 3

# %%
type(10 // 3) # Integer division, result is an integer 9/3 = 3
# Out:
# int

# %%
type(10 // 2)
# Out:
# int

# %% [markdown]
# ### ****Exponent**

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# > If a single one of the operands in an expression is a **float**, the result will also be a **float**, regardless of the other operands.

# %%
2.5 * 2
# Out:
# 5.0

# %%
int(2.5 * 2)
# Out:
# 5

# %% [markdown]
# ### Ordering
# - PEMDAS LR
#     - ()
#     - **
#     - (*)
#     - /
#     - (+)
#     - (-)

# %%
print(3 * 3 + 3 / 3 - 3)
# Out:
# 7.0
